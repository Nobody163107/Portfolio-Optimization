# %%
import pandas as pd

# %%
a = {"hello" : 1}
b = pd.DataFrame(a, index = [0])
b.to_csv(r"C:\Users\Praneeth Tadi\Documents\Projects\Portfolio Optimization\Portfolio-Optimization\data\raw\data.csv")
